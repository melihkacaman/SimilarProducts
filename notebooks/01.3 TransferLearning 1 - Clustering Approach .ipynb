# %% [markdown]
# This will be the first study for the dataset which we have just extracted.
# In this work, we begin with a Feature Extractor model. Also, we will be using Clustering Algorihtm with
# ~ Melih Kaçaman - 12/12/2022

# %% [markdown]
# # Creating Models Using Keras Functional API

# %%
SHAPE_WITH_CHANNELS = (224, 224, 3)
SHAPE = (224, 224)

# %%
import tensorflow as tf 

base_model = tf.keras.applications.EfficientNetB0(include_top=False)
# I'm not going to fine-tune this model.
base_model.trainable = False

inputs = tf.keras.layers.Input(shape=SHAPE_WITH_CHANNELS, name='input_layer')
x = base_model(inputs)
outputs = tf.keras.layers.GlobalAvgPool2D(name='global_average_pooling_layer')(x)

model_0 = tf.keras.Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 4s 0us/step

# %%
img_to_array_custom = tf.keras.preprocessing.image.img_to_array
load_img_custom = tf.keras.preprocessing.image.load_img

# %%
import tensorflow_hub as hub
import numpy as np

def get_embeddings_img(path):
    model = hub.KerasLayer('https://tfhub.dev/tensorflow/efficientnet/lite0/feature-vector/2')
    image = load_img_custom(path, target_size=SHAPE)
    image = img_to_array_custom(image)
    image = np.expand_dims(image, axis=0)

    embeddings = model(image)

    return embeddings

# %%
# path = '../datasets/dataset_cv3/brand_08/1-0CD-VR029/2145.png'
# res2 = get_embeddings_img(path)
# res2.shape
# Out:
# TensorShape([1, 1280])

# %%
dir = '../datasets/dataset1/brand_08/all/'
data_tf = tf.keras.preprocessing.image_dataset_from_directory(
    directory=dir,
    image_size=(224, 224),
    label_mode=None,
    batch_size=32
)
# Out:
# Found 242 files belonging to 1 classes.

# %% [markdown]
# - Embeddings shapes are correct, so we can move on with tensorflow batch-dataset.

# %%
ds = data_tf.unbatch()
images = ds = list(ds.map(lambda x: x))

# %%
# ds = data_tf.unbatch()
# images = list(ds.map(lambda x, y: x))
# labels = list(ds.map(lambda x, y: y)) 

# len(images), len(labels)

# %%
from sys import getsizeof 

getsizeof(images)
# Out:
# 2200

# %%
labels[0]

# %%
labels = np.array(labels)

# %%
images = np.array(list(map(lambda image: image.numpy().reshape(224, 224, 3), images)))

# %%
embeddings = model_0.predict(images)
# Out:
# 8/8 [==============================] - 6s 616ms/step

# %%
images.shape, labels.shape, embeddings.shape
# Out:
# ((1108, 224, 224, 3), (1108, 109), (1108, 1280))

# %% [markdown]
# # Cluestering
#
# ## Model C_1
# - We will be dealing with the dataset that includes just extracted inputs using K-Means.

# %%
from sklearn.cluster import KMeans

kmeans_model = KMeans(n_clusters=10).fit(embeddings)
kmeans_model.labels_
# Out:
# array([8, 1, 6, 5, 0, 6, 2, 6, 7, 6, 3, 6, 3, 8, 6, 9, 4, 0, 2, 9, 8, 1,
#        7, 7, 7, 7, 9, 5, 8, 3, 6, 6, 2, 0, 5, 4, 1, 6, 3, 0, 9, 1, 8, 4,
#        6, 4, 9, 7, 2, 2, 7, 9, 7, 0, 8, 4, 9, 6, 2, 6, 8, 0, 2, 8, 4, 4,
#        8, 6, 6, 9, 4, 6, 2, 1, 4, 8, 6, 9, 4, 0, 6, 9, 5, 4, 3, 1, 3, 6,
#        9, 4, 4, 6, 5, 4, 6, 3, 6, 6, 8, 7, 4, 2, 7, 4, 4, 9, 4, 5, 6, 8,
#        6, 8, 7, 8, 9, 2, 2, 9, 9, 9, 7, 5, 7, 7, 9, 7, 6, 6, 9, 6, 8, 6,
#        6, 6, 8, 9, 7, 6, 0, 3, 6, 8, 9, 6, 5, 9, 0, 1, 9, 9, 2, 3, 4, 8,
#        0, 7, 0, 6, 5, 1, 4, 6, 9, 6, 9, 9, 7, 3, 6, 8, 7, 9, 6, 9, 2, 5,
#        2, 1, 8, 0, 6, 8, 3, 0, 4, 6, 4, 4, 1, 7, 8, 4, 8, 6, 3, 8, 6, 9,
#        7, 1, 3, 9, 6, 6, 6, 6, 9, 6, 7, 4, 8, 5, 8, 3, 7, 8, 6, 6, 8, 6,
#        3, 3, 1, 4, 8, 3, 2, 6, 6, 7, 4, 2, 4, 2, 2, 3, 6, 4, 9, 1, 1, 6])

# %%
len(set(kmeans_model.labels_))
# Out:
# 10

# %%
kmeans_model.predict(embeddings[0, :].reshape(1, -1))
# Out:
# array([8])

# %%
kmeans_model.predict(embeddings[1, :].reshape(1, -1))
# Out:
# array([1])

# %% [markdown]
# ### Model C_1: Visualization

# %%
import pandas as pd 
unique, counts = np.unique(kmeans_model.labels_, return_counts=True)

val_counts = pd.DataFrame({'columns': unique, 'counts': counts})
val_counts.head()
# Out:
#    columns  counts
# 0        0      13
# 1        1      14
# 2        2      18
# 3        3      18
# 4        4      29

# %%
np.mean(val_counts.counts)
# Out:
# 24.2

# %%
val_counts[val_counts.counts == 14]
# Out:
#    columns  counts
# 1        1      14

# %%
clustering_result = pd.DataFrame({'cluster':kmeans_model.labels_})
clustering_result.head()
# Out:
#    cluster
# 0        8
# 1        1
# 2        6
# 3        5
# 4        0

# %%
idxs = list(clustering_result[clustering_result.cluster == 3].index)
idxs
# Out:
# [10,
#  12,
#  29,
#  38,
#  84,
#  86,
#  95,
#  139,
#  151,
#  167,
#  182,
#  194,
#  200,
#  213,
#  220,
#  221,
#  225,
#  235]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

def show_images(idxs, images, row = 1): 
    plt.figure(figsize=(15, 12))
    for i in range(len(idxs)):
        plt.subplot(row, 3, i+1)
        plt.axis('off')
        plt.imshow(np.array(images[idxs[i]], np.int32)) 

show_images(idxs, images, row=6)

# %%
idxs = list(clustering_result[clustering_result.cluster == 0].index)
idxs
# Out:
# [4, 17, 33, 39, 53, 61, 79, 138, 146, 154, 156, 179, 183]

# %%
show_images(idxs, images, row = 5)

# %%
idxs = list(clustering_result[clustering_result.cluster == 1].index)
show_images(idxs, images, row = 5)

# %% [markdown]
# ## Model C_2: Using Elbow Method

# %%
from scipy.spatial.distance import cdist
K = range(20, len(labels)) 

distortions = []
inertias = []
mapping1 = {}
mapping2 = {} 

for k in K:
    # Building and fitting the model
    kmeanModel = KMeans(n_clusters=k).fit(embeddings)
  
    distortions.append(sum(np.min(cdist(embeddings, kmeanModel.cluster_centers_,
                                        'euclidean'), axis=1)) / embeddings.shape[0])
    inertias.append(kmeanModel.inertia_)
  
    mapping1[k] = sum(np.min(cdist(embeddings, kmeanModel.cluster_centers_,
                                   'euclidean'), axis=1)) / embeddings.shape[0]
    mapping2[k] = kmeanModel.inertia_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [70], in <cell line: 9>()
#       7 mapping2 = {}
#       9 for k in K:
#      10     # Building and fitting the model
# ---> 11     kmeanModel = KMeans(n_clusters=k).fit(embeddings)
#      13     distortions.append(sum(np.min(cdist(embeddings, kmeanModel.cluster_centers_,
#      14                                         'euclidean'), axis=1)) / embeddings.shape[0])
#      15     inertias.append(kmeanModel.inertia_)
#
# File ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1179, in KMeans.fit(self, X, y, sample_weight)
#    1175 best_inertia, best_labels = None, None
#    1177 for i in range(self._n_init):
#    1178     # Initialize centers
# -> 1179     centers_init = self._init_centroids(
#    1180         X, x_squared_norms=x_squared_norms, init=init, random_state=random_state
#    1181     )
#    1182     if self.verbose:
#    1183         print("Initialization complete")
#
# File ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1090, in KMeans._init_centroids(self, X, x_squared_norms, init, random_state, init_size)
#    1087     n_samples = X.shape[0]
#    1089 if isinstance(init, str) and init == "k-means++":
# -> 1090     centers, _ = _kmeans_plusplus(
#    1091         X,
#    1092         n_clusters,
#    1093         random_state=random_state,
#    1094         x_squared_norms=x_squared_norms,
#    1095     )
#    1096 elif isinstance(init, str) and init == "random":
#    1097     seeds = random_state.permutation(n_samples)[:n_clusters]
#
# File ~\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:218, in _kmeans_plusplus(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#     215 np.clip(candidate_ids, None, closest_dist_sq.size - 1, out=candidate_ids)
#     217 # Compute distances to center candidates
# --> 218 distance_to_candidates = _euclidean_distances(
#     219     X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True
#     220 )
#     222 # update closest distances squared and potential for each candidate
#     223 np.minimum(closest_dist_sq, distance_to_candidates, out=distance_to_candidates)
#
# File ~\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:368, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     363         YY = row_norms(Y, squared=True)[np.newaxis, :]
#     365 if X.dtype == np.float32:
#     366     # To minimize precision issues with float32, we compute the distance
#     367     # matrix on chunks of X and Y upcast to float64
# --> 368     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     369 else:
#     370     # if dtype is already float64, no need to chunk and upcast
#     371     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#
# File ~\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:559, in _euclidean_distances_upcast(X, XX, Y, YY, batch_size)
#     556     d = distances[y_slice, x_slice].T
#     558 else:
# --> 559     Y_chunk = Y[y_slice].astype(np.float64)
#     560     if YY is None:
#     561         YY_chunk = row_norms(Y_chunk, squared=True)[np.newaxis, :]
#
# KeyboardInterrupt:
